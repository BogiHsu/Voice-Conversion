# %%
# colab only
# mount google drive
import os
from google.colab import drive
drive.mount('/content/gdrive')
os.chdir('/content/gdrive/My Drive/2019 AI Summer School')

# %%
# install required packages
# !pip3 install -r requirements.txt

# %%
# run demo directly
# !python3 convert.py
